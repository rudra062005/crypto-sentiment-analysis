# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# better visuals
sns.set(style="whitegrid")

# show all columns
pd.set_option('display.max_columns', None)

# %%
# Load historical data
trader_df = pd.read_csv("data/historical_data.csv")

# Load fear greed index data
sentiment_df = pd.read_csv("data/fear_greed_index.csv")

# %%
# First 5 rows
trader_df.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
sentiment_df.head()
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
trader_df.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# dtype: int64

# %%
sentiment_df.isnull().sum()
# Out:
# timestamp         0
# value             0
# classification    0
# date              0
# dtype: int64

# %%
trader_df.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  Start Position  \
# count    211224.000000  2.112240e+05  2.112240e+05    2.112240e+05
# mean      11414.723350  4.623365e+03  5.639451e+03   -2.994625e+04
# std       29447.654868  1.042729e+05  3.657514e+04    6.738074e+05
# min           0.000005  8.740000e-07  0.000000e+00   -1.433463e+07
# 25%           4.854700  2.940000e+00  1.937900e+02   -3.762311e+02
# 50%          18.280000  3.200000e+01  5.970450e+02    8.472793e+01
# 75%         101.580000  1.879025e+02  2.058960e+03    9.337278e+03
# max      109004.000000  1.582244e+07  3.921431e+06    3.050948e+07
#
#           Closed PnL      Order ID            Fee      Trade ID     Timestamp
# count  211224.000000  2.112240e+05  211224.000000  2.112240e+05  2.112240e+05
# mean       48.749001  6.965388e+10       1.163967  5.628549e+14  1.737744e+12
# std       919.164828  1.835753e+10       6.758854  3.257565e+14  8.689920e+09
# ...

# %%
trader_df.columns
sentiment_df.columns
# Out:
# Index(['timestamp', 'value', 'classification', 'date'], dtype='object')

# %%
# Convert to datetime
trader_df['Timestamp IST'] = pd.to_datetime(
    trader_df['Timestamp IST'],
    dayfirst=True
)

trader_df['date'] = trader_df['Timestamp IST'].dt.date

# %%
sentiment_df['date'] = pd.to_datetime(sentiment_df['date']).dt.date

# %%
trader_df[['Timestamp IST', 'date']].head()
# Out:
#         Timestamp IST        date
# 0 2024-12-02 22:50:00  2024-12-02
# 1 2024-12-02 22:50:00  2024-12-02
# 2 2024-12-02 22:50:00  2024-12-02
# 3 2024-12-02 22:50:00  2024-12-02
# 4 2024-12-02 22:50:00  2024-12-02

# %%
sentiment_df[['date', 'classification']].head()
# Out:
#          date classification
# 0  2018-02-01           Fear
# 1  2018-02-02   Extreme Fear
# 2  2018-02-03           Fear
# 3  2018-02-04   Extreme Fear
# 4  2018-02-05   Extreme Fear

# %%
merged_df = pd.merge(trader_df, sentiment_df, on='date', how='inner')

# %%
merged_df.head()
merged_df.shape
# Out:
# (211218, 20)

# %%
merged_df['classification'].value_counts()
# Out:
# classification
# Fear             61837
# Greed            50303
# Extreme Greed    39992
# Neutral          37686
# Extreme Fear     21400
# Name: count, dtype: int64

# %%
merged_df.groupby('classification')['Closed PnL'].mean()
# Out:
# classification
# Extreme Fear     34.537862
# Extreme Greed    67.892861
# Fear             54.290400
# Greed            42.743559
# Neutral          34.307718
# Name: Closed PnL, dtype: float64

# %%
plt.figure()
merged_df.groupby('classification')['Closed PnL'].mean().plot(kind='bar')
plt.title("Average PnL: Fear vs Greed")
plt.ylabel("Average Profit")
plt.show()

# %%
merged_df['is_profit'] = merged_df['Closed PnL'] > 0

# %%
merged_df.groupby('classification')['is_profit'].mean()
# Out:
# classification
# Extreme Fear     0.370607
# Extreme Greed    0.464943
# Fear             0.420768
# Greed            0.384828
# Neutral          0.396991
# Name: is_profit, dtype: float64

# %%
merged_df.groupby('classification')['Size USD'].mean()
# Out:
# classification
# Extreme Fear     5349.731843
# Extreme Greed    3112.251565
# Fear             7816.109931
# Greed            5736.884375
# Neutral          4782.732661
# Name: Size USD, dtype: float64

# %%
merged_df.groupby('classification')['Closed PnL'].std()
# Out:
# classification
# Extreme Fear     1136.056091
# Extreme Greed     766.828294
# Fear              935.355438
# Greed            1116.028390
# Neutral           517.122220
# Name: Closed PnL, dtype: float64

# %%
# Win rate
merged_df.groupby('classification')['is_profit'].mean()

# Trade size
merged_df.groupby('classification')['Size USD'].mean()

# Risk (volatility)
merged_df.groupby('classification')['Closed PnL'].std()
# Out:
# classification
# Extreme Fear     1136.056091
# Extreme Greed     766.828294
# Fear              935.355438
# Greed            1116.028390
# Neutral           517.122220
# Name: Closed PnL, dtype: float64

# %%
merged_df.groupby('classification')['is_profit'].mean()
merged_df.groupby('classification')['Size USD'].mean()
# Out:
# classification
# Extreme Fear     5349.731843
# Extreme Greed    3112.251565
# Fear             7816.109931
# Greed            5736.884375
# Neutral          4782.732661
# Name: Size USD, dtype: float64

# %%
sns.boxplot(x='classification', y='Closed PnL', data=merged_df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Key Findings
#
# ## Extreme Greed yields highest profitability
# ## Fear shows high capital deployment (contrarian behavior)
# ## Extreme Fear has highest volatility (risky)
# ## Neutral markets provide lowest returns
# ## Greed phases show overconfidence and unstable outcomes

# %% [markdown]
# # Trading Strategy Recommendations
#
# ## Use trend-following in Extreme Greed
# ## Use buy-the-dip strategy in Fear
# ## Avoid trading in Neutral markets
# ## Apply strict risk management in Extreme Fear

# %%
merged_df.groupby('date')['Closed PnL'].sum().plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# Trader performance is strongly influenced by market sentiment. Extreme Greed provides the most favorable conditions due to strong trends, while Fear phases offer opportunities for contrarian strategies. Neutral markets lack directional advantage, making them less profitable.
